# %% [markdown]
# __cleanup_git_repos__
# _First version:  January 1, 2026_
#
# This script cleans up unused git repos from a subscription

# %%
import os
import requests
import pandas as pd
from tqdm import tqdm
from datetime import datetime, timedelta, timezone

# Constants

GITHUB_API = "https://api.github.com"

#TOKEN = os.getenv("GITHUB_TOKEN")
TOKEN = "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"
if not TOKEN:
    raise SystemExit("ERROR: Please set GITHUB_TOKEN environment variable.")

HEADERS = {
    "Authorization": f"Bearer {TOKEN}",
    "Accept": "application/vnd.github+json"
}

print("Environment ready.")
# Out:
# Environment ready.

# %%
# Get the authenticated user's username

def get_authenticated_user():
    r = requests.get(f"{GITHUB_API}/user", headers=HEADERS)
    r.raise_for_status()
    return r.json()["login"]

username = get_authenticated_user()
username
# Out:
# 'mjbeattie'

# %%
# List repositories where the user is a collaborator

def list_collaborator_repos():
    repos = []
    page = 1

    while True:
        r = requests.get(
            f"{GITHUB_API}/user/repos",
            headers=HEADERS,
            params={"affiliation": "collaborator", "per_page": 100, "page": page}
        )
        r.raise_for_status()
        data = r.json()
        if not data:
            break

        repos.extend(data)
        page += 1

    return repos

collab_repos = list_collaborator_repos()
len(collab_repos)
# Out:
# 18

# %%
# Create a DataFrame of collaborator repos and save to CSV

df = pd.DataFrame([{
    "full_name": r["full_name"],
    "html_url": r["html_url"],
    "pushed_at": r["pushed_at"],
    "updated_at": r["updated_at"],
    "owner": r["owner"]["login"]
} for r in collab_repos])

df.to_csv("collaborator_repos.csv", index=False)
df.head()
# Out:
#                                            full_name  \
# 0                   Abhinov7402/Katragadda_OUDSA5900
# 1  adityakasturi8/Analysis-of-Disrupted-Transport...
# 2                   AjayDasAkunuri/Akunuri_OUDSA5900
# 3                   Ajordan10/ProfessionalPractice23
# 4                            ak3737/ASGHAR_OUDSA5900
#
#                                             html_url             pushed_at  \
# 0  https://github.com/Abhinov7402/Katragadda_OUDS...  2025-12-27T20:12:30Z
# 1  https://github.com/adityakasturi8/Analysis-of-...  2022-07-30T21:20:29Z
# 2  https://github.com/AjayDasAkunuri/Akunuri_OUDS...  2025-11-08T01:37:12Z
# 3  https://github.com/Ajordan10/ProfessionalPract...  2023-07-17T23:06:19Z
# 4         https://github.com/ak3737/ASGHAR_OUDSA5900  2024-04-27T04:59:09Z
#
#              updated_at           owner
# 0  2025-12-27T20:12:34Z     Abhinov7402
# 1  2025-02-10T20:44:12Z  adityakasturi8
# 2  2025-10-10T00:06:39Z  AjayDasAkunuri
# 3  2023-06-06T21:14:52Z       Ajordan10
# 4  2024-04-27T04:59:12Z          ak3737

# %%
# Set a threshold to unsubscribe from repos
months = 6
cutoff = datetime.now(timezone.utc) - timedelta(days=30 * months)

df["pushed_at_dt"] = pd.to_datetime(df["pushed_at"], utc=True)

filtered_df = df[df["pushed_at_dt"] < cutoff]
filtered_df.head(), len(filtered_df)
# Out:
# (                                           full_name  \
#  1  adityakasturi8/Analysis-of-Disrupted-Transport...
#  3                   Ajordan10/ProfessionalPractice23
#  4                            ak3737/ASGHAR_OUDSA5900
#  5                       aksharaArcot/Arcot_OUDSA5900
#  6                      amakhlouf1/Makhlouf_OUDSA5900
#
#                                              html_url             pushed_at  \
#  1  https://github.com/adityakasturi8/Analysis-of-...  2022-07-30T21:20:29Z
#  3  https://github.com/Ajordan10/ProfessionalPract...  2023-07-17T23:06:19Z
#  4         https://github.com/ak3737/ASGHAR_OUDSA5900  2024-04-27T04:59:09Z
#  5    https://github.com/aksharaArcot/Arcot_OUDSA5900  2021-03-13T03:13:27Z
#  6   https://github.com/amakhlouf1/Makhlouf_OUDSA5900  2023-08-21T17:16:14Z
#
#               updated_at           owner              pushed_at_dt
#  1  2025-02-10T20:44:12Z  adityakasturi8 2022-07-30 21:20:29+00:00
#  3  2023-06-06T21:14:52Z       Ajordan10 2023-07-17 23:06:19+00:00
#  4  2024-04-27T04:59:12Z          ak3737 2024-04-27 04:59:09+00:00
#  5  2021-03-13T03:17:37Z    aksharaArcot 2021-03-13 03:13:27+00:00
#  6  2023-08-21T17:16:14Z      amakhlouf1 2023-08-21 17:16:14+00:00  ,
#  192)

# %%
# Unsubscribe from all watched repositories meeting filter criteria

def unsubscribe_from_all():
    print("Unsubscribing from watched repositories...")
    page = 1
    total_unsubscribed = 0

    while True:
        r = requests.get(
            f"{GITHUB_API}/user/subscriptions",
            headers=HEADERS,
            params={"per_page": 100, "page": page}
        )
        r.raise_for_status()
        subs = r.json()
        if not subs:
            break

        for repo in tqdm(subs, desc=f"Page {page}"):
            full = repo["full_name"]
            del_r = requests.delete(
                f"{GITHUB_API}/repos/{full}/subscription",
                headers=HEADERS
            )
            if del_r.status_code in (204, 202):
                total_unsubscribed += 1

        page += 1

    return total_unsubscribed

unsubscribed_count = unsubscribe_from_all()
unsubscribed_count
# Out:
# Unsubscribing from watched repositories...
# Page 1: 100%|██████████| 17/17 [00:06<00:00,  2.80it/s]
# 17

# %%
# Remove self as collaborator from filtered repositories

def remove_self_as_collaborator(df, username, dry_run=True):
    removed = []
    failed = []

    for full in tqdm(df["full_name"], desc="Removing collaborator access"):
        if dry_run:
            removed.append(full)
            continue

        r = requests.delete(
            f"{GITHUB_API}/repos/{full}/collaborators/{username}",
            headers=HEADERS
        )

        if r.status_code in (204, 202):
            removed.append(full)
        else:
            failed.append((full, r.status_code, r.text))

    return removed, failed

removed, failed = remove_self_as_collaborator(filtered_df, username, dry_run=True)
len(removed), len(failed)
# Out:
# Removing collaborator access: 100%|██████████| 192/192 [00:00<?, ?it/s]
# (192, 0)

# %%
# Uncomment to actually remove self as collaborator

removed, failed = remove_self_as_collaborator(filtered_df, username, dry_run=False)
removed, failed
# Out:
# Removing collaborator access: 100%|██████████| 192/192 [01:44<00:00,  1.84it/s]
# (['adityakasturi8/Analysis-of-Disrupted-Transportation-Network-in-a-Multi-Hazard-Scenario',
#   'Ajordan10/ProfessionalPractice23',
#   'ak3737/ASGHAR_OUDSA5900',
#   'aksharaArcot/Arcot_OUDSA5900',
#   'amakhlouf1/Makhlouf_OUDSA5900',
#   'anandamoyb/bhattacharya_OUDSA5900',
#   'anozman/Nozka_OUDSA5900',
#   'asvasan1974/Srinivasan_OUDSA5900',
#   'AustinMould/Mould_OUDSA5900',
#   'ayohamzat96/hamzat_OUDSA5900',
#   'AzmaynInkishaf/INKISHAF_OUDSA5900',
#   'b-khoshroo/Khoshroo_OUDSA5900',
#   'balanagarajunarra-1/narra_OUDSA5900',
#   'barbosaMatheus/RulPrediction',
#   'bharawdwajrahul/Bharadwaj_OUDSA5900',
#   'Bhavana-parupalli/PARUPALLI_OUDSA5900',
#   'Bhavesh-Kilaru/NLP-Using-Federated-Learning',
#   'bhavyareddykanuganti/kanuganti_OUDSA5900',
#   'BigyaB/Bhattarai_OUDSA5900',
#   'biniwollo/Fall24-DSA-5900',
#   'bins0000/Binsaleh_OUDSA5900',
#   'Biswas-N/recommendation-systems-for-yelp',
#   'blevick7/Levicki_OUDSA5900',
#   'bmkeafer2112/Keafer_OUDSA5900',
#   'bwSimpkins/Simpkins_OUDSA5900',
#   'caxton-muchono/Muchono_OUDSA5900',
#   'cdoudican/DSA-5900-Project',
#   'cggdonner/Donner_OUDSA5900',
#   'chang1261/Kim_OUDSA5900',
#   'CharlesTJohnson/Johnson_OUDSA5900',
#   'chimnadiri/JOHAN_OUDSA5900',
#   'CIRDL/Group6_OUDSA5900',
#   'ClareAx/Axthelm_OUDSA5900',
#   'claudiacorrales-27/Corrales_OUDSA5900',
#   'cobeyw/Weemes_OUDSA5900',
#   'community/Global-Campus-Teachers',
#   'ConnorBehnen/Behnen_OUDSA5900',
#   'd-sanoj/doddapaneni_OUDSA5900',
#   'daedalus404/PracticumFall2023',
#   'Daniel-Carpenter/DSA-Practicum',
#   'DanielTAdd/Prediction_of_Petrophysical_Properties_5900',
#   'Deepthiy196/yekkanti_OUDSA5900',
#   'diegoou8/HERNANDEZ_OUDSA5900',
#   'DuchaHapsari/Hapsari_OUDSA5900',
#   'dywang0323/DSA_5900',
#   'edh108/hernandez_OUDSA5900',
#   'ElahehJafarigol/Federated-Machine-Learning-in-Predictive-Maintenance-of-Jet-Engines',
#   'enavarrete7/Navarrete_OUDSA5900',
#   'ESB1997/Baker_OUDSA5900',
#   'estebanud17/Ugarte_DSA5900',
#   'esthernevener/Nevener_OUDSA5900',
#   'estrickler1/Strickler_Ethan_OUDSA5900',
#   'FrancisOyebanji/oyebanji_OUDSA5900',
#   'Gowthami-Chikka/Chikka-_OUDSA5900',
#   'gunash-Khn/Khankishiyeva_OUDSA5900',
#   'haixiaolu/FAA-Pliot-License-Renewal-Forecasting',
#   'hanna-hart/Hart_OUDSA5900',
#   'hariappi/Federated_Learning_WESAD',
#   'harikavengala-1/Vengala_OUDSA5900',
#   'Hoov6299/Hoover_OUDSA5900',
#   'HotelTango314/dsa5900',
#   'iamchinedu/Nwosu_OUDSA5900',
#   'Issa03112009/Haddad_OUDSA5900',
#   'jackappleyard/appleyard_OUDSA5900',
#   'Jacob-Unterbrink/Unterbrink_OUDSA5900',
#   'jacostam1/Acosta_OUDSA5900',
#   'jakelcoop/COOPER__OUDSA5900',
#   'jamalmohamed/Hassan_OUDSA5900',
#   'jawhipple/WHIPPLE_OUDSA5900',
#   'jayasimhareddy27/DSAI-5900-course',
#   'jntran08/Speech_Recognition_Analysis',
#   'JoFlynn22/Flynn_OUDSA5900',
#   'jone2900/jones_OUDSA5900',
#   'Jordan-Daugherty-1/Daugherty_OUDSA5900',
#   'josudha10/Jonnakuti_OUDSA5900',
#   'jsturges28/Image-Recreation',
#   'jt-reich/Reich_OUDSA5900',
#   'Judah99/-odiachi-_OUDSA5900',
#   'JUmaMaheshwarReddy/Jangalapalli_OUDSA5900',
#   'Karen5630/Ochie_OUDSA5900',
#   'kaustubhpandeou/Pande_OUDSA5900',
#   'Kayodex29/Sanni_OUDSA5900',
#   'keerthiOU/mora_OUDSA5900',
#   'KiranKumarMurugan/Murugan_OUDSA5900',
#   'Kovida98/Mothukuri_OUDSA5900',
#   'kylefan48/Ferguson_OUDSA5900',
#   'kylejames2424/james_OUDSA5900',
#   'LakshmiBhavaniUppaluri/Uppaluri_OUDSA5900',
#   'Leama-Tah/Tah_OUDSA5900',
#   'Lisa63989/Napierala_OUDSA5900',
#   'm-harikiran/DRL-AT',
#   'mall0060/Mallapu_OUDSA5900',
#   'Mansura-Roly/Roly_OUDSA5900',
#   'marshallrbaldwin/Practicum_Project_DSA_5900',
#   'mat-crick/Das_OUDSA5900',
#   'mdeepika01/METTU_OUDSA5900',
#   'Meghana-127/Nagendra_OUDSA5900',
#   'MeghnathReddy/Challa_OUDSA5900',
#   'melbenito9/Benito_OUDSA5900',
#   'mendgithub/mendez_OUDSA5900',
#   'MichaelVladovich/VLADOVICH_OUDSA5900',
#   'miguelmbingo/Mbingo_OUDSA5900',
#   'mikeolubode/olubode_OUDSA5900',
#   'mitchell15/MUSACK_OUDSA5900',
#   'mjkhalaf/Alkhalaf_OUDSA5900',
#   'mmquaynor/Quaynor_OUDSA5900',
#   'MohamedSalih23/SALIH-OUDSA5900',
#   'N-David-N/methUseClassification',
#   'Najafbeygi/Najafbeygi_OUDSA5900',
#   'nbridges7/Bridges_OUDSA5900',
#   'nilamreshim/Reshim_OUDSA5900',
#   'NimzNimzz/Robert_OUDSA5900',
#   'NimzNimzz/Sanni_OUDSA5900',
#   'nipuquayum/DSA5900',
#   'NoahRatcliffe1/Ratcliffe_OUDSA5900',
#   'nosliwes/wilson_OUDSA5900',
#   'nushraZ/Zannat_OUDSA5900',
#   'oiza-ajoku/ajok_OUDSA5900',
#   'oizaochi/DSA5900-001',
#   'oluchi-osuagwu/Osuagwu_OUDSA5900',
#   'OnyRamdago/Ramananandroniaina_OUDSA5900',
#   'orkhankhn/khankishiyev_OUDSA5900',
#   'OUlukemcdougal/McDougal_OUDSA5900',
#   'Oyin-Zobo/Predict_ROP_ML',
#   'PatrickSearceyOU/searcey_OUDSA5900',
#   'paulinacastillov/CASTILLO_OUDSA5900',
#   'pavanvasanth33/KOMMINENI_OUDSA5900-',
#   'pdmechedge/1_dwivedi_OUDSA5900',
#   'pdmechedge/DWIVEDI_OUDSA5900',
#   'PenTompkins/Tompkins_OUDSA5900',
#   'peterh4/DSA-5900-Project',
#   'plucero33/OUDSA5900',
#   'pranav-cpu/Vichare_OUDSA5900',
#   'Prasuna-mit/Protein-Protein-Interacation-Interface-Analysis',
#   'prudhvik97/YARLAGADDA_OUDSA5900',
#   'PurushothamVadde/Yelp_Business_Review_Classification',
#   'Rachana137/Homelessness-in-the-United-States',
#   'Rachana137/VELLAMPALLI_OUDSA5900',
#   'Rachanadsa/Thotireddy_OUDSA5900',
#   'rachellb/Bennett_OUDSA5900',
#   'rafado/Cerqueira_OUDSA5900',
#   'rafia37/device-habitat',
#   'rahulkataram07/Kataram_OUDSA5900',
#   'raj768/Saha_OUDSA5900',
#   'Rajashekar0004/GeoLocation-Inference',
#   'Rajasri-kolli/Cesareandelivery-prediction',
#   'Rami-Reddy-Y/Yekkanti_OUDSA5900',
#   'ramrao0102/DSA5900-Project',
#   'RavillaMounica/Ravilla_OUDSA5900',
#   'rheahanks/Hanks_OUDSA5900',
#   'Rithsek99/ngem_OUDSA5900',
#   'rlhull6/dsastackoverflow',
#   'rosa0002/Rosa_OUDSA5900',
#   'RunshengZhou/ZHOU_OUDSA5900',
#   'RunshengZhou/Zhou_OUDSA5900-Fall-2021',
#   'saikiran-reddy/mamidi_OUDSA5900',
#   'SaisriPotluru/Potluru_OUDSA5900',
#   'saket2431/Srivastava_OUDSA5900',
#   'samuelrodrigonza/rodriguez_OUDSA5900-',
#   'Shahzad-Ansari/DSA-CAPSTONE',
#   'shai0002/Social-Media-Analysis-on-Missing-and-Murdered-Indigenous-Women-using-Data-Science-and-Analytics',
#   'Shimairi/shimamura_OUDSA5900',
#   'sivareddy-thummuri/Thummuri_OUDSA5900',
#   'Sonaxy/COVID19-predictions-using-HTS',
#   'songyuan93/YAO_OUDSA5900',
#   'Sowmyareddy30/Gangireddy_OUDSA59000',
#   'steimel60/Steimel_OUDSA5900',
#   'tahamitofique/tofique_OUDSA5900',
#   'Tarini-Singh/Singh_OUDSA5900',
#   'TengnanYao/Yao_DSA5900',
#   'ThaoVyNgo/Predict-RUL-maintenance',
#   'thesoftmachine/Pratt_OUDSA5900',
#   'thok0001/Thokala__OUDSA5900',
#   'ThreeStrings/herman_OUDSA5900',
#   'tientran56151/Tran_OUDSA5900',
#   'tobeanya/Anyaezu_OUDSA5900',
#   'tuckwise/Capps_OUDSA5900',
#   'TylerBrown117/Brown_OUDSA5900',
#   'usma92/Balan_OUDSA5900',
#   'Varshithavn/Vasireddy_OUDSA5900',
#   'Varun-Chowdary/Hallucination-detector',
#   'Vidyadhari6/Maddukuri_OUDSA5900',
#   'vigneshv1cky/DSA_5900-Professional-Practice-Spring-2025',
#   'wboncal/Boncal_OUDSA5900',
#   'whellier/Practicum-Project',
#   'willowarana/arana_OUDSA5900',
#   'YangZhou-1/Zhou_OUDSA5900',
#   'Yashasvi9849/Musku_5900',
#   'yhlines/LINOUDSA5900',
#   'ZacharyBurton/Burton_OUDSA5900',
#   'ZackaryHoyt/HOYT_OUDSA5900',
#   'zknepp1/AI-Models-for-Investment-Portfolio-Development'],
#  [])

# %%
# Summary Report

report = {
    "total_collaborator_repos": len(df),
    "repos_filtered_for_removal": len(filtered_df),
    "unsubscribed_repos": unsubscribed_count,
    "would_remove_collaborator_access": len(removed),
    "failed_removals": len(failed)
}

report
# Out:
# {'total_collaborator_repos': 210,
#  'repos_filtered_for_removal': 192,
#  'unsubscribed_repos': 17,
#  'would_remove_collaborator_access': 192,
#  'failed_removals': 0}
